# %%
import pandas as pd

# %%
# Read the File

# %%
df = pd.read_csv(r'C:\Users\Admin\Downloads\shopping_behavior.csv')

# %%
df.head()
# Out:
#   Customer ID   Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0           1  55.0   Male         Blouse  Clothing                   53.0
# 1           2  19.0   Male        Sweater  Clothing                   64.0
# 2           3  50.0   Male          Jeans  Clothing                   73.0
# 3           4  21.0   Male        Sandals  Footwear                   90.0
# 4           5  45.0   Male         Blouse  Clothing                   49.0
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3901 entries, 0 to 3900
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3901 non-null   object
#  1   Age                     3900 non-null   float64
#  2   Gender                  3899 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3899 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   float64
#  6   Location                3898 non-null   object
#  7   Size                    3897 non-null   object
#  8   Color                   3898 non-null   object
#  9   Season                  3899 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3898 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3899 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Purchase Amount (USD)  Review Rating  Previous Purchases
# count  3900.000000            3900.000000    3863.000000         3900.000000
# mean     44.068462              59.764359       3.750065           25.351538
# std      15.207589              23.685392       0.716983           14.447125
# min      18.000000              20.000000       2.500000            1.000000
# 25%      31.000000              39.000000       3.100000           13.000000
# 50%      44.000000              60.000000       3.800000           25.000000
# 75%      57.000000              81.000000       4.400000           38.000000
# max      70.000000             100.000000       5.000000           50.000000

# %%
df.describe(include='all')
# Out:
#        Customer ID          Age Gender Item Purchased  Category  \
# count         3901  3900.000000   3899           3900      3899
# unique        3901          NaN      2             25         4
# top              1          NaN   Male         Blouse  Clothing
# freq             1          NaN   2651            171      1736
# mean           NaN    44.068462    NaN            NaN       NaN
# std            NaN    15.207589    NaN            NaN       NaN
# min            NaN    18.000000    NaN            NaN       NaN
# 25%            NaN    31.000000    NaN            NaN       NaN
# 50%            NaN    44.000000    NaN            NaN       NaN
# 75%            NaN    57.000000    NaN            NaN       NaN
# max            NaN    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3898  3897   3898    3899    3863.000000
# ...

# %%
df.shape
# Out:
# (3901, 18)

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        1
# Gender                     2
# Item Purchased             1
# Category                   2
# Purchase Amount (USD)      1
# Location                   3
# Size                       4
# Color                      3
# Season                     2
# Review Rating             38
# Subscription Status        3
# Shipping Type              1
# Discount Applied           2
# Promo Code Used            2
# Previous Purchases         1
# Payment Method             2
# Frequency of Purchases     1
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 44.06846153846154

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\694922604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Gender'].unique()
# Out:
# array(['Male', nan, 'Female'], dtype=object)

# %%
df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\3657246551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
df['Item Purchased'].unique()
# Out:
# array(['Blouse', 'Sweater', 'Jeans', 'Sandals', 'Sneakers', 'Shirt',
#        'Shorts', 'Coat', 'Handbag', 'Shoes', 'Dress', 'Skirt',
#        'Sunglasses', 'Pants', 'Jacket', 'Hoodie', 'Jewelry', 'T-shirt',
#        'Scarf', 'Hat', 'Socks', 'Backpack', 'Belt', 'Boots', 'Gloves',
#        nan], dtype=object)

# %%
df['Item Purchased'].mode()
# Out:
# 0     Blouse
# 1    Jewelry
# 2      Pants
# Name: Item Purchased, dtype: object

# %%
df['Item Purchased'].fillna(df['Item Purchased'].mode()[0], inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\2340225288.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Item Purchased'].fillna(df['Item Purchased'].mode()[0], inplace=True)

# %%
df['Item Purchased'].isnull().sum()
# Out:
# 0

# %%
df['Category'].isnull().sum()
# Out:
# 2

# %%
df['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories', nan],
#       dtype=object)

# %%
df['Category'].mode()
# Out:
# 0    Clothing
# Name: Category, dtype: object

# %%
df['Category'].fillna(df['Category'].mode()[0], inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\1735344843.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Category'].fillna(df['Category'].mode()[0], inplace=True)

# %%
df['Purchase Amount (USD)'].unique()
# Out:
# array([ 53.,  64.,  73.,  90.,  49.,  20.,  85.,  34.,  97.,  31.,  68.,
#         72.,  51.,  81.,  36.,  38.,  48.,  62.,  37.,  88.,  22.,  25.,
#         56.,  94.,  79.,  67.,  91.,  33.,  69.,  45.,  60.,  76.,  39.,
#        100.,  21.,  43.,  54.,  55.,  30.,  28.,  59.,  24.,  83.,  46.,
#         70.,  29.,  26.,  58.,  96.,  40.,  32.,  95.,  41.,  47.,  99.,
#         87.,  92.,  98.,  89.,  35.,  75.,  65.,  86.,  84.,  77.,  27.,
#         23.,  74.,  80.,  42.,  61.,  82.,  78.,  93.,  50.,  57.,  66.,
#         44.,  52.,  71.,  63.,  nan])

# %%
df['Purchase Amount (USD)'].mean()
# Out:
# 59.76435897435898

# %%
df['Purchase Amount (USD)'].median()
# Out:
# 60.0

# %%
# Outlier
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(x=df['Purchase Amount (USD)'])
plt.show()

# %%
df['Purchase Amount (USD)'].fillna(df['Purchase Amount (USD)'].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\1410533747.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Purchase Amount (USD)'].fillna(df['Purchase Amount (USD)'].mean(),inplace=True)

# %%
df['Purchase Amount (USD)'].isnull().sum()
# Out:
# 0

# %%
df['Location'].unique()
# Out:
# array(['Kentucky', 'Maine', 'Massachusetts', 'Rhode Island', 'Oregon',
#        'Wyoming', 'Montana', 'Louisiana', 'West Virginia', 'Missouri',
#        'Arkansas', 'Hawaii', 'Delaware', 'New Hampshire', 'New York',
#        'Alabama', 'Mississippi', 'North Carolina', 'California',
#        'Oklahoma', 'Florida', 'Texas', 'Nevada', 'Kansas', 'Colorado',
#        'North Dakota', 'Illinois', 'Indiana', 'Arizona', 'Alaska',
#        'Tennessee', 'Ohio', 'New Jersey', 'Maryland', 'Vermont',
#        'New Mexico', 'South Carolina', 'Idaho', 'Pennsylvania',
#        'Connecticut', 'Utah', 'Virginia', 'Georgia', 'Nebraska', 'Iowa',
#        'South Dakota', 'Minnesota', nan, 'Washington', 'Wisconsin',
#        'Michigan'], dtype=object)

# %%
df['Location'].mode()
# Out:
# 0    Montana
# Name: Location, dtype: object

# %%
df['Location'].fillna(df['Location'].mode()[0],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\3879254974.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Location'].fillna(df['Location'].mode()[0],inplace=True)

# %%
df['Location'].isnull().sum()
# Out:
# 0

# %%
df['Size'].unique()
# Out:
# array(['L', 'S', 'M', 'XL', nan], dtype=object)

# %%
df['Size'].mode()
# Out:
# 0    M
# Name: Size, dtype: object

# %%
df.groupby('Category')['Size'].apply(lambda x: x.mode())
# Out:
# Category
# Accessories  0    M
# Clothing     0    M
# Footwear     0    M
# Outerwear    0    M
# Name: Size, dtype: object

# %%
df['Size'].fillna(df['Size'].mode()[0],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\3637014270.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Size'].fillna(df['Size'].mode()[0],inplace=True)

# %%
df['Size'].isnull().sum()
# Out:
# 0

# %%
df['Color'].mode()
# Out:
# 0    Olive
# Name: Color, dtype: object

# %%
df.groupby('Category')['Color'].apply(lambda x: x.mode())
# Out:
# Category
# Accessories  0    Olive
# Clothing     0     Teal
# Footwear     0    Olive
# Outerwear    0     Blue
#              1    Olive
# Name: Color, dtype: object

# %%
df['Color'].isnull().sum()
# Out:
# 3

# %%
df['Color']=df.groupby('Category')['Color'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
df['Season'].unique()
# Out:
# array(['Winter', 'Spring', 'Summer', 'Fall', nan], dtype=object)

# %%
df['Season'].mode()
# Out:
# 0    Spring
# Name: Season, dtype: object

# %%
df['Season'].fillna(df['Season'].mode()[0],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\1678814713.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Season'].fillna(df['Season'].mode()[0],inplace=True)

# %%
df['Season'].isnull().sum()
# Out:
# 0

# %%
df['Subscription Status'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df['Subscription Status'].mode()
# Out:
# 0    No
# Name: Subscription Status, dtype: object

# %%
df['Subscription Status'].fillna(df['Subscription Status'].mode()[0],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\2611647190.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Subscription Status'].fillna(df['Subscription Status'].mode()[0],inplace=True)

# %%
df['Subscription Status'].isnull().sum()
# Out:
# 0

# %%
df['Shipping Type'].unique()
# Out:
# array(['Express', 'Free Shipping', 'Next Day Air', 'Standard',
#        '2-Day Shipping', 'Store Pickup', nan], dtype=object)

# %%
df.groupby('Category')['Shipping Type'].apply(lambda x: x.mode())
# Out:
# Category
# Accessories  0     Store Pickup
# Clothing     0         Standard
# Footwear     0    Free Shipping
# Outerwear    0    Free Shipping
# Name: Shipping Type, dtype: object

# %%
df['Shipping Type']=df.groupby('Category')['Shipping Type'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
df['Shipping Type'].isnull().sum()
# Out:
# 0

# %%
df['Discount Applied'].unique()
# Out:
# array(['Yes', nan, 'No'], dtype=object)

# %%
df['Discount Applied'].mode()
# Out:
# 0    No
# Name: Discount Applied, dtype: object

# %%
df['Discount Applied'].fillna(df['Discount Applied'].mode()[0],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\3604058853.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Discount Applied'].fillna(df['Discount Applied'].mode()[0],inplace=True)

# %%
df['Discount Applied'].isnull().sum()
# Out:
# 0

# %%
df['Promo Code Used'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df['Promo Code Used'].mode()
# Out:
# 0    No
# Name: Promo Code Used, dtype: object

# %%
df['Promo Code Used'].fillna(df['Promo Code Used'].mode()[0],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\3583815751.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Promo Code Used'].fillna(df['Promo Code Used'].mode()[0],inplace=True)

# %%
df['Promo Code Used'].isnull().sum()
# Out:
# 0

# %%
df['Previous Purchases'].unique()
# Out:
# array([14.,  2., 23., 49., 31., 19.,  8.,  4., 26., 10., 37., 34., 44.,
#        36., 17., 46., 50., 22., 32., 40., 16., 13.,  7., 41., 45., 38.,
#        48., 18., 15., 25., 39., 35., 29., 21., 43.,  3.,  5., 24., 42.,
#        47., 28., 20., 33.,  1.,  9., 12., 27., 11., 30.,  6., nan])

# %%
df['Previous Purchases'].mean()
# Out:
# 25.35153846153846

# %%
df['Previous Purchases'].median()
# Out:
# 25.0

# %%
sns.boxplot(x=df['Previous Purchases'])
plt.show()

# %%
df['Previous Purchases'].fillna(df['Previous Purchases'].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\1618129308.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Previous Purchases'].fillna(df['Previous Purchases'].mean(),inplace=True)

# %%
df['Previous Purchases'].isnull().sum()
# Out:
# 0

# %%
df['Payment Method'].unique()
# Out:
# array(['Venmo', 'Cash', 'Credit Card', 'PayPal', 'Bank Transfer',
#        'Debit Card', nan], dtype=object)

# %%
df['Payment Method'].mode()
# Out:
# 0    PayPal
# Name: Payment Method, dtype: object

# %%
df['Payment Method'].fillna(df['Payment Method'].mode()[0],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\3093757813.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Payment Method'].fillna(df['Payment Method'].mode()[0],inplace=True)

# %%
df['Payment Method'].isnull().sum()
# Out:
# 0

# %%
df['Frequency of Purchases'].unique()
# Out:
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months', nan], dtype=object)

# %%
df['Frequency of Purchases'].mode()
# Out:
# 0    Every 3 Months
# Name: Frequency of Purchases, dtype: object

# %%
df['Frequency of Purchases'].fillna(df['Frequency of Purchases'].mode()[0],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14076\218910328.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Frequency of Purchases'].fillna(df['Frequency of Purchases'].mode()[0],inplace=True)

# %%
df['Frequency of Purchases'].isnull().sum()
# Out:
# 0

# %%
df['Review Rating'].unique()
# Out:
# array([3.1, 3.5, 2.7, 2.9, 3.2, 2.6, 4.8, 4.1, 4.9, 4.5, 4.7, 2.8, 4.6,
#        3.3, 4.4, 3.6, 5. , 4. , nan, 4.2, 3.7, 3.9, 3. , 3.8, 3.4, 4.3,
#        2.5])

# %%
sns.boxplot(x=df['Review Rating'])
plt.show()

# %%
df['Review Rating']=df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df['Review Rating'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns =df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df= df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
# Create a column age_group

labels = ['Young','Adult','Middle_aged','Senior']
df['age_group'] = pd.qcut(df['age'], q=4, labels = labels)

# %%
df[['age','age_group']]
# Out:
#             age    age_group
# 0     55.000000  Middle_aged
# 1     19.000000        Young
# 2     50.000000  Middle_aged
# 3     21.000000        Young
# 4     45.000000  Middle_aged
# ...         ...          ...
# 3896  52.000000  Middle_aged
# 3897  46.000000  Middle_aged
# 3898  44.000000        Adult
# 3899  52.000000  Middle_aged
# 3900  44.068462  Middle_aged
#
# [3901 rows x 2 columns]

# %%
# purchase frequency days
frequency_mapping = {
    'Fortnightly':14,
    'Weekly':7,
    'Monthly':30,
    'Quarterly':90,
    'Bi-weekly':14,
    'Annually':365,
    'Every 3 months':30
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                     14.0            Fortnightly
# 1                     14.0            Fortnightly
# 2                      7.0                 Weekly
# 3                      7.0                 Weekly
# 4                    365.0               Annually
# 5                      7.0                 Weekly
# 6                     90.0              Quarterly
# 7                      7.0                 Weekly
# 8                    365.0               Annually
# 9                     90.0              Quarterly

# %%
df['frequency_of_purchases']
# Out:
# 0          Fortnightly
# 1          Fortnightly
# 2               Weekly
# 3               Weekly
# 4             Annually
#              ...
# 3896         Bi-Weekly
# 3897         Quarterly
# 3898            Weekly
# 3899         Quarterly
# 3900    Every 3 Months
# Name: frequency_of_purchases, Length: 3901, dtype: object

# %%
df[['discount_applied','promo_code_used']].tail(50)
# Out:
#      discount_applied promo_code_used
# 3851               No              No
# 3852               No              No
# 3853               No              No
# 3854               No              No
# 3855               No              No
# 3856               No              No
# 3857               No              No
# 3858               No              No
# 3859               No              No
# 3860               No              No
# 3861               No              No
# 3862               No              No
# 3863               No              No
# 3864               No              No
# 3865               No              No
# 3866               No              No
# 3867               No              No
# 3868               No              No
# 3869               No              No
# 3870               No              No
# 3871               No              No
# 3872               No              No
# 3873               No              No
# 3874               No              No
# ...

# %%
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# False

# %%
df.drop('promo_code_used',axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='object')

# %%
df.head()
# Out:
#   customer_id   age gender item_purchased  category  purchase_amount  \
# 0           1  55.0   Male         Blouse  Clothing             53.0
# 1           2  19.0   Male        Sweater  Clothing             64.0
# 2           3  50.0   Male          Jeans  Clothing             73.0
# 3           4  21.0   Male        Sandals  Footwear             90.0
# 4           5  45.0   Male         Blouse  Clothing             49.0
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied  previous_purchases payment_method  \
# ...

# %%
import mysql.connector
from sqlalchemy import create_engine,text
from sqlalchemy.engine import URL

# %%
conn=URL.create(
     drivername = "mysql+pymysql",
    host='localhost',
    username='root',
    password='snehal123',
    port= 3306,
    database='shopping_behavior'

)

engine = create_engine(conn)
conn = engine.connect()

table_name='customer'

df.to_sql(table_name, engine, if_exists='replace',index=False)

print('Data successfully loaded in MySQL table')
# Out:
# Data successfully loaded in MySQL table
